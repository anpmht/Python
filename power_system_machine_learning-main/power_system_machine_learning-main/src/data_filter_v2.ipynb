# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("./data/power.csv")
# print(df)

# a = [750,1705,2500,3500,4300,5250,6100,7100,8000,8800,9750,10750,11500,12500,13400,14250,15250,16100,17000,18000,18750,19750,20500,21500,22350,23350,24250,25100,26000,26750,27750,28600,29600,30500,31400,32300,33100,34100,35500,36000,36700,37600,38550,39500,40400,41350,42200,43000,44100,44400,45700,46700,47500,48500,49300,50300,51200,52100,53000,53800,54750,55700,56500,57500,58400,59350,60300,61000,62000,62800,63800,64700,65600,66500,67400,68300,69200,70100,71000,71800,72700,73700,74500,75500,76350,77300,78250,79100,80000,80900,81750,83650,83600,84500,85400,86300,87200,88100,89000,89900,90800,91700,92600,93500,94400,95250,96200,97100,98000,98900,99750,100700,101600,102500,103400,104300,105200,106100,107000,108800]
# Out:
#     19.97636  50.0000066914481  49.9999535163987  49.9999818463893  \
# 10  20.09632         50.000006         49.999957         49.999983
#
#     122.509843781543  69.1854104745006  -19.7126585388061  171.982595717237
# 10        122.494743          69.18154          -19.70429        171.971994

# %%
a = 105000
b = 108000
plt.figure(figsize=(17,4))
df["p1"][a:b].plot()
plt.show()
plt.figure(figsize=(17,4))
df["p2"][a:b].plot()
plt.show()
plt.figure(figsize=(17,4))
df["p3"][a:b].plot()
plt.show()
a = [750,1705,2500,3500,4300,5250,6100,7100,8000,8800,9750,10750,11500,12500,13400,14250,15250,16100,17000,18000,18750,19750,20500,21500,22350,23350,24250,25100,26000,26750,27750,28600,29600,30500,31400,32300,33100,34100,35500,36000,36700,37600,38550,39500,40400,41350,42200,43000,44100,44400,45700,46700,47500,48500,49300,50300,51200,52100,53000,53800,54750,55700,56500,57500,58400,59350,60300,61000,62000,62800,63800,64700,65600,66500,67400,68300,69200,70100,71000,71800,72700,73700,74500,75500,76350,77300,78250,79100,80000,80900,81750,83650,83600,84500,85400,86300,87200,88100,89000,89900,90800,91700,92600,93500,94400,95250,96200,97100,98000,98900,99750,100700,101600,102500,103400,104300,105200,106100,107000,108800]

# %%
for n in a:
    new_df=df[n:n+1]
    new_df.to_csv('filtered_data.csv', mode='a', index=False, header=False)

# %%
df = pd.read_csv("filtered_data.csv")
plt.figure(figsize=(17,4))
plt.plot(df["p1"])
plt.show()
